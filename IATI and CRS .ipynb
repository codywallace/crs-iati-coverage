# %% [markdown]
# # Compare CRS Data to IATI Transactions

# %% [markdown]
# # Setup

# %% [markdown]
# Donor mapping and CRS aggregated output source: https://github\.com/akmiller01/ODSC\-CRS\-ODA\-comp/tree/main, 13/1/25

# %% [markdown]
# Read in files \- using data generated in Disbursements & Expenditures vs Flow

# %%
import pandas as pd
import numpy as np

# %%
crs_data = pd.read_csv("crs_aggregated_2014_2023.csv")
mapping = pd.read_csv("iati_donor_mapping_20241101.csv")
disb_exp_flow = pd.read_excel("dispexpvsflow_data.xlsx")

# %% [markdown]
# # Map IATI organisations to CRS

# %% [markdown]
# Mapping source: https://github\.com/akmiller01/ODSC\-CRS\-ODA\-comp/blob/main/iati\_donor\_mapping\_20241101\.csv

# %%
iati_mapped = mapping.merge(disb_exp_flow, left_on="reporting_org_ref",right_on="reportingorg_ref",how='left')
iati_mapped = iati_mapped.rename(columns={'comb_flowtype_code': 'category_code', 'comb_flowtype_codename': 'category_name'})
iati_mapped
# Out:
#        reporting_org_ref                            publisher_name  \
# 0            XM-DAC-2-10           Belgian Development Cooperation
# 1            XM-DAC-2-10           Belgian Development Cooperation
# 2            XM-DAC-2-10           Belgian Development Cooperation
# 3            XM-DAC-2-10           Belgian Development Cooperation
# 4            XM-DAC-2-10           Belgian Development Cooperation
# ...                  ...                                       ...
# 805441  US-EIN-941655673  The William and Flora Hewlett Foundation
# 805442  US-EIN-941655673  The William and Flora Hewlett Foundation
# 805443  US-EIN-941655673  The William and Flora Hewlett Foundation
# 805444  US-EIN-941655673  The William and Flora Hewlett Foundation
# 805445  US-EIN-941655673  The William and Flora Hewlett Foundation
#
#         donor_code                            donor_name comments  \
# 0                2                               Belgium      NaN
# 1                2                               Belgium      NaN
# 2                2                               Belgium      NaN
# 3                2                               Belgium      NaN
# 4                2                               Belgium      NaN
# ...            ...                                   ...      ...
# 805441        1624  William and Flora Hewlett Foundation      NaN
# 805442        1624  William and Flora Hewlett Foundation      NaN
# 805443        1624  William and Flora Hewlett Foundation      NaN
# 805444        1624  William and Flora Hewlett Foundation      NaN
# 805445        1624  William and Flora Hewlett Foundation      NaN
#
#                          iatiidentifier  reportingorg_ref  \
# 0                      XM-DAC-2-10-1012       XM-DAC-2-10
# 1                      XM-DAC-2-10-1012       XM-DAC-2-10
# 2                      XM-DAC-2-10-1012       XM-DAC-2-10
# 3                      XM-DAC-2-10-1012       XM-DAC-2-10
# 4                      XM-DAC-2-10-1012       XM-DAC-2-10
# ...                                 ...               ...
# 805441  US-EIN-941655673-2024-04803-GRA  US-EIN-941655673
# 805442  US-EIN-941655673-2024-04833-GRA  US-EIN-941655673
# 805443  US-EIN-941655673-2024-04860-GRA  US-EIN-941655673
# 805444  US-EIN-941655673-2024-04871-GRA  US-EIN-941655673
# 805445  US-EIN-941655673-2024-04876-GRA  US-EIN-941655673
#
#         transactiontype_code transactiontype_codename    year  sum_value_usd  \
# 0                        3.0             Disbursement  2016.0   4.327568e+04
# 1                        3.0             Disbursement  2017.0   3.811171e+05
# 2                        3.0             Disbursement  2018.0   1.320229e+06
# 3                        3.0             Disbursement  2019.0   8.491214e+05
# 4                        3.0             Disbursement  2020.0   6.749012e+05
# ...                      ...                      ...     ...            ...
# 805441                   3.0             Disbursement  2024.0   1.100000e+05
# 805442                   3.0             Disbursement  2024.0   1.500000e+05
# 805443                   3.0             Disbursement  2024.0   4.000000e+04
# 805444                   3.0             Disbursement  2024.0   2.500000e+05
# 805445                   3.0             Disbursement  2024.0   1.000000e+05
#
#         flowtype_code flowtype_codename  defaultflowtype_code  \
# 0                 NaN               NaN                  10.0
# 1                 NaN               NaN                  10.0
# 2                 NaN               NaN                  10.0
# 3                 NaN               NaN                  10.0
# 4                 NaN               NaN                  10.0
# ...               ...               ...                   ...
# 805441            NaN               NaN                  30.0
# 805442            NaN               NaN                  30.0
# 805443            NaN               NaN                  30.0
# 805444            NaN               NaN                  30.0
# 805445            NaN               NaN                  30.0
#
#            defaultflowtype_codename  category_code  \
# 0                               ODA           10.0
# 1                               ODA           10.0
# 2                               ODA           10.0
# 3                               ODA           10.0
# 4                               ODA           10.0
# ...                             ...            ...
# 805441  Private Development Finance           30.0
# 805442  Private Development Finance           30.0
# 805443  Private Development Finance           30.0
# 805444  Private Development Finance           30.0
# 805445  Private Development Finance           30.0
#
#                       category_name
# 0                               ODA
# 1                               ODA
# 2                               ODA
# 3                               ODA
# 4                               ODA
# ...                             ...
# 805441  Private Development Finance
# 805442  Private Development Finance
# 805443  Private Development Finance
# 805444  Private Development Finance
# 805445  Private Development Finance
#
# [805446 rows x 17 columns]

# %% [markdown]
# # Aggregate

# %% [markdown]
# Group IATI transaction values by year, donor, and flow type\.

# %%
iati_mapped_agg = iati_mapped.groupby(['year','donor_code', 'donor_name','category_code','category_name'])['sum_value_usd'].sum().reset_index()
iati_mapped_agg['iati_usd_mil'] = iati_mapped_agg['sum_value_usd']/1000000
iati_mapped_agg = iati_mapped_agg.drop('sum_value_usd', axis=1)
iati_mapped_agg
# Out:
#        year  donor_code                                     donor_name  \
# 0    2010.0           2                                        Belgium
# 1    2010.0           3                                        Denmark
# 2    2010.0           5                                        Germany
# 3    2010.0           6                                          Italy
# 4    2010.0           7                                    Netherlands
# ..      ...         ...                                            ...
# 714  2024.0        1050   WHO-Strategic Preparedness and Response Plan
# 715  2024.0        1311  Global Alliance for Vaccines and Immunization
# 716  2024.0        1312                                    Global Fund
# 717  2024.0        1601                Bill & Melinda Gates Foundation
# 718  2024.0        1624           William and Flora Hewlett Foundation
#
#      category_code                category_name  iati_usd_mil
# 0             10.0                          ODA    229.873999
# 1             10.0                          ODA   1880.802198
# 2             10.0                          ODA    456.390627
# 3             10.0                          ODA     16.164210
# 4             10.0                          ODA   3824.749728
# ..             ...                          ...           ...
# 714           10.0                          ODA   1549.641596
# 715           10.0                          ODA   2154.921850
# 716           10.0                          ODA   4378.750510
# 717           30.0  Private Development Finance   3323.404193
# 718           30.0  Private Development Finance    138.400085
#
# [719 rows x 6 columns]

# %%
iati_mapped_agg.to_csv("iati_donor_disb_exp_by_flowtype_2014_2023.csv", index=False)

# %% [markdown]
# Group IATI transaction values by year and flow type\.

# %%
iati_year_aidtype = iati_mapped.groupby(['year','category_code','category_name'])['sum_value_usd'].sum().reset_index()
iati_year_aidtype['iati_usd_mil'] = iati_year_aidtype['sum_value_usd']/1000000
iati_year_aidtype = iati_year_aidtype.drop('sum_value_usd', axis=1)
iati_year_aidtype
# Out:
#       year  category_code                category_name   iati_usd_mil
# 0   2010.0           10.0                          ODA   30346.133150
# 1   2010.0           20.0                          OOF   17507.870978
# 2   2010.0           21.0        Non-export credit OOF    1384.733220
# 3   2010.0           30.0  Private Development Finance     107.566545
# 4   2010.0           35.0               Private Market       0.000000
# ..     ...            ...                          ...            ...
# 84  2024.0           10.0                          ODA  180948.599135
# 85  2024.0           20.0                          OOF   20982.110898
# 86  2024.0           21.0        Non-export credit OOF    9530.504503
# 87  2024.0           30.0  Private Development Finance    3540.760697
# 88  2024.0           50.0                  Other flows    3864.631814
#
# [89 rows x 4 columns]

# %% [markdown]
# Group CRS data by year and flow type\.

# %%
crs_data_agg = crs_data.groupby(['year','category_code','category_name'])['value'].sum().reset_index()
crs_data_agg
# Out:
#     year  category_code                category_name          value
# 0   2014             10                          ODA  166173.154968
# 1   2014             21        Non-export credit OOF   56034.880130
# 2   2014             30  Private Development Finance    2849.778452
# 3   2015             10                          ODA  167463.479341
# 4   2015             21        Non-export credit OOF   71561.232181
# 5   2015             30  Private Development Finance    3242.273631
# 6   2016             10                          ODA  181520.878808
# 7   2016             21        Non-export credit OOF   64844.249058
# 8   2016             30  Private Development Finance    4062.015936
# 9   2017             10                          ODA  191479.739666
# 10  2017             21        Non-export credit OOF   69120.481248
# 11  2017             30  Private Development Finance    7108.284098
# 12  2018             10                          ODA  196012.370152
# 13  2018             21        Non-export credit OOF   76709.534536
# 14  2018             30  Private Development Finance    7683.122155
# 15  2019             10                          ODA  191461.924803
# 16  2019             21        Non-export credit OOF   77059.888087
# 17  2019             30  Private Development Finance    7904.330837
# 18  2020             10                          ODA  223320.267458
# 19  2020             21        Non-export credit OOF   96804.156269
# 20  2020             30  Private Development Finance    9437.150719
# 21  2021             10                          ODA  235411.111079
# 22  2021             21        Non-export credit OOF  100665.875682
# 23  2021             30  Private Development Finance   10987.825119
# 24  2022             10                          ODA  277090.186570
# 25  2022             21        Non-export credit OOF  102754.171804
# 26  2022             30  Private Development Finance   10762.967513
# 27  2023             10                          ODA  287994.165010
# 28  2023             21        Non-export credit OOF   98935.248336
# 29  2023             60                          PSI   10596.033693

# %% [markdown]
# # Join and compare

# %% [markdown]
# Compare IATI transactions to CRS data, looking at year, donor, and flow type\.

# %%
compare = crs_data.merge(iati_mapped_agg, on=['year','donor_code', 'donor_name','category_code','category_name'],how='outer')
compare
# Out:
#         year  donor_code                                     donor_name  \
# 0     2010.0         2.0                                        Belgium
# 1     2010.0         3.0                                        Denmark
# 2     2010.0         5.0                                        Germany
# 3     2010.0         6.0                                          Italy
# 4     2010.0         7.0                                    Netherlands
# ...      ...         ...                                            ...
# 2011  2024.0      1050.0   WHO-Strategic Preparedness and Response Plan
# 2012  2024.0      1311.0  Global Alliance for Vaccines and Immunization
# 2013  2024.0      1312.0                                    Global Fund
# 2014  2024.0      1601.0                Bill & Melinda Gates Foundation
# 2015  2024.0      1624.0           William and Flora Hewlett Foundation
#
#       category_code                category_name  value  iati_usd_mil
# 0              10.0                          ODA    NaN    229.873999
# 1              10.0                          ODA    NaN   1880.802198
# 2              10.0                          ODA    NaN    456.390627
# 3              10.0                          ODA    NaN     16.164210
# 4              10.0                          ODA    NaN   3824.749728
# ...             ...                          ...    ...           ...
# 2011           10.0                          ODA    NaN   1549.641596
# 2012           10.0                          ODA    NaN   2154.921850
# 2013           10.0                          ODA    NaN   4378.750510
# 2014           30.0  Private Development Finance    NaN   3323.404193
# 2015           30.0  Private Development Finance    NaN    138.400085
#
# [2016 rows x 7 columns]

# %%
compare.to_csv("crs_iati_donor_disb_exp_by_flowtype_2014_2023_comparison.csv", index=False)

# %%
compare['percent_difference'] = (compare['iati_usd_mil'] / compare['value']) * 100

# %%
compare
# Out:
#         year  donor_code                                     donor_name  \
# 0     2010.0         2.0                                        Belgium
# 1     2010.0         3.0                                        Denmark
# 2     2010.0         5.0                                        Germany
# 3     2010.0         6.0                                          Italy
# 4     2010.0         7.0                                    Netherlands
# ...      ...         ...                                            ...
# 2011  2024.0      1050.0   WHO-Strategic Preparedness and Response Plan
# 2012  2024.0      1311.0  Global Alliance for Vaccines and Immunization
# 2013  2024.0      1312.0                                    Global Fund
# 2014  2024.0      1601.0                Bill & Melinda Gates Foundation
# 2015  2024.0      1624.0           William and Flora Hewlett Foundation
#
#       category_code                category_name  value  iati_usd_mil  \
# 0              10.0                          ODA    NaN    229.873999
# 1              10.0                          ODA    NaN   1880.802198
# 2              10.0                          ODA    NaN    456.390627
# 3              10.0                          ODA    NaN     16.164210
# 4              10.0                          ODA    NaN   3824.749728
# ...             ...                          ...    ...           ...
# 2011           10.0                          ODA    NaN   1549.641596
# 2012           10.0                          ODA    NaN   2154.921850
# 2013           10.0                          ODA    NaN   4378.750510
# 2014           30.0  Private Development Finance    NaN   3323.404193
# 2015           30.0  Private Development Finance    NaN    138.400085
#
#       percent_difference
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 2011                 NaN
# 2012                 NaN
# 2013                 NaN
# 2014                 NaN
# 2015                 NaN
#
# [2016 rows x 8 columns]

# %%
compare.to_csv("crs_iati_donor_disb_exp_by_flowtype_2014_2023_comparison.csv", index=False)

# %% [markdown]
# Compare donor grouping aggregation across of flow-types.

# %%
import numpy as np

donor_group_compare = (
    compare
    .groupby(["year", "donor_code", "donor_name"], as_index=False)
    .agg(
        value=("value", "sum"),
        iati_usd_mil=("iati_usd_mil", "sum")
    )
)

donor_group_compare["percent_difference"] = np.where(
    out["value"] > 0,
    (out["iati_usd_mil"] / out["value"]) * 100,
    np.nan
)

donor_group_compare
# Out:
#         year  donor_code                                     donor_name  \
# 0     2010.0         2.0                                        Belgium
# 1     2010.0         3.0                                        Denmark
# 2     2010.0         5.0                                        Germany
# 3     2010.0         6.0                                          Italy
# 4     2010.0         7.0                                    Netherlands
# ...      ...         ...                                            ...
# 1508  2024.0      1050.0   WHO-Strategic Preparedness and Response Plan
# 1509  2024.0      1311.0  Global Alliance for Vaccines and Immunization
# 1510  2024.0      1312.0                                    Global Fund
# 1511  2024.0      1601.0                Bill & Melinda Gates Foundation
# 1512  2024.0      1624.0           William and Flora Hewlett Foundation
#
#       value  iati_usd_mil  percent_difference
# 0       0.0    229.873999                 NaN
# 1       0.0   1880.802198                 NaN
# 2       0.0    456.390627                 NaN
# 3       0.0     16.164210                 NaN
# 4       0.0   3840.203413                 NaN
# ...     ...           ...                 ...
# 1508    0.0   1549.641596                 NaN
# 1509    0.0   2154.921850                 NaN
# 1510    0.0   4378.750510                 NaN
# 1511    0.0   3323.404193                 NaN
# 1512    0.0    138.400085                 NaN
#
# [1513 rows x 6 columns]

# %%
donor_group_compare.to_csv("crs_iati_donor_disb_exp_comparison_2014_2023.csv", index=False)

# %% [markdown]
# Compare IATI transactions to CRS data, looking at year and flow type\.

# %%
compare_yearaid = crs_data_agg.merge(iati_year_aidtype, on=['year','category_code','category_name'],how='outer')
compare_yearaid['perc'] = (compare_yearaid['iati_usd_mil']/compare_yearaid['value'])*100
compare_yearaid
# Out:
#       year  category_code                category_name  value   iati_usd_mil  \
# 0   2010.0           10.0                          ODA    NaN   30346.133150
# 1   2010.0           20.0                          OOF    NaN   17507.870978
# 2   2010.0           21.0        Non-export credit OOF    NaN    1384.733220
# 3   2010.0           30.0  Private Development Finance    NaN     107.566545
# 4   2010.0           35.0               Private Market    NaN       0.000000
# ..     ...            ...                          ...    ...            ...
# 85  2024.0           10.0                          ODA    NaN  180948.599135
# 86  2024.0           20.0                          OOF    NaN   20982.110898
# 87  2024.0           21.0        Non-export credit OOF    NaN    9530.504503
# 88  2024.0           30.0  Private Development Finance    NaN    3540.760697
# 89  2024.0           50.0                  Other flows    NaN    3864.631814
#
#     perc
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 85   NaN
# 86   NaN
# 87   NaN
# 88   NaN
# 89   NaN
#
# [90 rows x 6 columns]
