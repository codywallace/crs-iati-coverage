# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: requests in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: pandas in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (2.1.4)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting noteql==0.7.4
#   Downloading noteql-0.7.4.tar.gz (12 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ijson
#   Downloading ijson-3.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 16.9 MB/s eta 0:00:00
# Collecting xmltodict
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Collecting duckdb-engine
#   Downloading duckdb_engine-0.15.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: psycopg2-binary in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from noteql==0.7.4->-r ./requirements.txt (line 7)) (2.9.9)
# Requirement already satisfied: sqlalchemy<2 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from noteql==0.7.4->-r ./requirements.txt (line 7)) (1.4.42)
# Requirement already satisfied: click in /root/venv/lib/python3.9/site-packages (from noteql==0.7.4->-r ./requirements.txt (line 7)) (8.1.8)
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: jinja2 in /root/venv/lib/python3.9/site-packages (from noteql==0.7.4->-r ./requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: lxml in /root/venv/lib/python3.9/site-packages (from noteql==0.7.4->-r ./requirements.txt (line 7)) (5.3.0)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 45.8 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing in /root/venv/lib/python3.9/site-packages (from noteql==0.7.4->-r ./requirements.txt (line 7)) (3.2.1)
# Collecting noteql-jinjasql
#   Downloading noteql-jinjasql-0.1.10.tar.gz (8.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.9/site-packages (from requests->-r ./requirements.txt (line 1)) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.9/site-packages (from requests->-r ./requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.9/site-packages (from requests->-r ./requirements.txt (line 1)) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.9/site-packages (from requests->-r ./requirements.txt (line 1)) (2024.12.14)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /root/venv/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (1.25.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->-r ./requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: greenlet!=0.4.17 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from sqlalchemy<2->noteql==0.7.4->-r ./requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: packaging>=21 in /root/venv/lib/python3.9/site-packages (from duckdb-engine->noteql==0.7.4->-r ./requirements.txt (line 7)) (24.2)
# Requirement already satisfied: duckdb>=0.5.0 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from duckdb-engine->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.9.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.9/site-packages (from jinja2->noteql==0.7.4->-r ./requirements.txt (line 7)) (3.0.2)
# Collecting notebook
#   Downloading notebook-7.3.2-py3-none-any.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 111.0 MB/s eta 0:00:00
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 47.2 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (6.29.5)
# Collecting jupyterlab
#   Downloading jupyterlab-4.3.4-py3-none-any.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 140.6 MB/s eta 0:00:00
# Collecting nbconvert
#   Downloading nbconvert-7.16.5-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 69.1 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: nest-asyncio in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: tornado>=6.1 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (6.4.1)
# Requirement already satisfied: pyzmq>=24 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (26.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in /root/venv/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (8.18.1)
# Requirement already satisfied: psutil in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (6.0.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (7.4.9)
# Requirement already satisfied: comm>=0.1.1 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: traitlets>=5.4.0 in /root/venv/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /root/venv/lib/python3.9/site-packages (from ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.1.7)
# Collecting jupyterlab-widgets~=3.0.12
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 64.8 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0.12
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 171.8 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /root/venv/lib/python3.9/site-packages (from jupyter-console->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (2.19.1)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /root/venv/lib/python3.9/site-packages (from jupyter-console->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (3.0.50)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /root/venv/lib/python3.9/site-packages (from jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (8.6.1)
# Requirement already satisfied: setuptools>=40.8.0 in /root/venv/lib/python3.9/site-packages (from jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (75.8.0)
# Collecting httpx>=0.25.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 31.1 MB/s eta 0:00:00
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Collecting jupyterlab-server<3,>=2.27.1
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=1.2.2 in /root/venv/lib/python3.9/site-packages (from jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (2.2.1)
# Collecting notebook-shim>=0.2
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 88.6 MB/s eta 0:00:00
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 29.1 MB/s eta 0:00:00
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.1.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 18.5 MB/s eta 0:00:00
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 55.3 MB/s eta 0:00:00
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 45.0 MB/s eta 0:00:00
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: nbformat>=5.7 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from nbconvert->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (5.10.4)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /root/venv/lib/python3.9/site-packages (from async-lru>=1.0.0->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (4.12.2)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Collecting anyio
#   Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 38.9 MB/s eta 0:00:00
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 26.6 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.20 in /root/venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (3.21.0)
# Requirement already satisfied: exceptiongroup in /root/venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /root/venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.17.2)
# Requirement already satisfied: decorator in /root/venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /root/venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: stack-data in /root/venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: entrypoints in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /root/venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (4.3.6)
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting prometheus-client>=0.9
#   Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 20.9 MB/s eta 0:00:00
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting websocket-client>=1.7
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 15.6 MB/s eta 0:00:00
# Collecting jupyter-events>=0.11.0
#   Downloading jupyter_events-0.11.0-py3-none-any.whl (19 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: babel>=2.10 in /root/venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (2.16.0)
# Collecting json5>=0.9.0
#   Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from nbformat>=5.7->nbconvert->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (2.20.0)
# Requirement already satisfied: wcwidth in /root/venv/lib/python3.9/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.2.13)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /root/venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (2023.12.1)
# Requirement already satisfied: attrs>=22.2.0 in /root/venv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (24.3.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /toolkit-cache/0.2.2/python3.9/kernel-libs/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.20.0)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-3.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.3 in /root/venv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (6.0.2)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /root/venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pure-eval in /root/venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /root/venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /root/venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (2.1.0)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: cffi>=1.0.1 in /root/venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (1.17.1)
# Requirement already satisfied: pycparser in /root/venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->noteql==0.7.4->-r ./requirements.txt (line 7)) (2.22)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 27.2 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Building wheels for collected packages: noteql, noteql-jinjasql
#   Building wheel for noteql (setup.py): started
#   Building wheel for noteql (setup.py): finished with status 'done'
#   Created wheel for noteql: filename=noteql-0.7.4-py3-none-any.whl size=10044 sha256=7821271cd3357637c35f878cc4e81eb089f6d3382e61c86b193b9f3dc82cc60d
#   Stored in directory: /root/.cache/pip/wheels/04/74/d5/8cce01c0b174a5801b3d6f95bcbc37df47ad9393813b0f0848
#   Building wheel for noteql-jinjasql (setup.py): started
#   Building wheel for noteql-jinjasql (setup.py): finished with status 'done'
#   Created wheel for noteql-jinjasql: filename=noteql_jinjasql-0.1.10-py3-none-any.whl size=5254 sha256=a4c82726d0f205845f3da481fdc7bb4ce8d1c142c211a980a1147d9c28ab7494
#   Stored in directory: /root/.cache/pip/wheels/70/e2/79/c4672a616dd8b3ac2e1b9a6b57fa45289768cc8ca6d8cb927b
# Successfully built noteql noteql-jinjasql
# Installing collected packages: webencodings, ijson, xmltodict, widgetsnbextension, websocket-client, webcolors, uri-template, types-python-dateutil, tinycss2, terminado, soupsieve, sniffio, send2trash, rfc3986-validator, rfc3339-validator, python-json-logger, python-dotenv, prometheus-client, pandocfilters, overrides, mistune, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, h11, fqdn, et-xmlfile, defusedxml, bleach, async-lru, openpyxl, noteql-jinjasql, jupyter-server-terminals, httpcore, duckdb-engine, beautifulsoup4, arrow, argon2-cffi-bindings, anyio, isoduration, ipywidgets, httpx, argon2-cffi, jupyter-console, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, noteql
# Successfully installed anyio-4.8.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 beautifulsoup4-4.12.3 bleach-6.2.0 defusedxml-0.7.1 duckdb-engine-0.15.0 et-xmlfile-2.0.0 fqdn-1.5.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 ijson-3.3.0 ipywidgets-8.1.5 isoduration-20.11.0 json5-0.10.0 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.11.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.4 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-3.0.13 mistune-3.1.0 nbclient-0.10.2 nbconvert-7.16.5 notebook-7.3.2 notebook-shim-0.2.4 noteql-0.7.4 noteql-jinjasql-0.1.10 openpyxl-3.1.5 overrides-7.7.0 pandocfilters-1.5.1 prometheus-client-0.21.1 python-dotenv-1.0.1 python-json-logger-3.2.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.6 terminado-0.18.1 tinycss2-1.4.0 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.13 xmltodict-0.14.2
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
